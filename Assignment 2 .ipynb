# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sb

# %%
import pandas

# %%
from bs4 import BeautifulSoup

# %%
mb=pandas.read_csv("C:\\Users\\Admin\\Downloads\\Ram\\largest_internet_company.csv")

# %%
mb
# Out:
#      Rank            Company  Revenue ($B)  F.Y.  Employees  Market cap. ($B)  \
# 0       1             Amazon        386.06  2020  1298000.0           1668.00
# 1       2           Alphabet        182.53  2020   135301.0           1524.00
# 2       3             JD.com        114.97  2020   310000.0            115.96
# 3       4               Meta         85.96  2020    58604.0            842.49
# 4       5            Tencent         74.31  2020    85858.0            763.11
# ..    ...                ...           ...   ...        ...               ...
# 96     96           Flexport          1.27  2020     2000.0               NaN
# 97     97            LogMeIn          1.26  2019     3974.0              4.21
# 98     98         Craigslist          1.00  2018     1000.0               NaN
# 99     99               Grab          1.00  2018     6000.0               NaN
# 100   100  Ultimate Software          1.00  2018     5000.0               NaN
#
# ...

# %%
mpp=mb.tail()

# %%
mpp
# Out:
#      Rank            Company  Revenue ($B)  F.Y.  Employees  Market cap. ($B)  \
# 96     96           Flexport          1.27  2020     2000.0               NaN
# 97     97            LogMeIn          1.26  2019     3974.0              4.21
# 98     98         Craigslist          1.00  2018     1000.0               NaN
# 99     99               Grab          1.00  2018     6000.0               NaN
# 100   100  Ultimate Software          1.00  2018     5000.0               NaN
#
#         Headquarters  Founded                     Industry
# 96     San Francisco     2013  Software freight forwarding
# 97            Boston     2003                     Software
# 98     San Francisco     1995                  Classifieds
# 99         Singapore     2012               Transportation
# 100  Weston, Florida     1993                     Software

# %%
plt.scatter(mpp['Rank'],mpp['Employees'])

# %%
plt.bar(mb['Founded'],mb['F.Y.'])
# Out:
# <BarContainer object of 101 artists>

# %%
plt.plot(mb['F.Y.'],mb['Founded'],linestyle='dotted')

# %%
plt.pie(mpp['Rank'],labels=mpp['F.Y.'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1e646dba640>,
# ...
#  [Text(0.8981360828490972, 0.6350996588603082, '2020'),
#   Text(-0.30621289758296855, 1.0565195981872948, '2019'),
#   Text(-1.0991861975076946, 0.04230488398016843, '2018'),
#   Text(-0.37327516177968817, -1.0347297490641447, '2018'),
#   Text(0.881555031196891, -0.6579215203741619, '2018')])

# %%
time=np.arange(0,1000,0.5)

# %%
time
# Out:
# array([0.000e+00, 5.000e-01, 1.000e+00, ..., 9.985e+02, 9.990e+02,
#        9.995e+02])

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.47942554,  0.84147098, ..., -0.50247916,
#        -0.02646075,  0.45603617])

# %%
plt.plot(time,amplitude)

# %%
plt.plot(mpp['Rank'],mpp['Employees'])

# %%
sb.set(style='darkgrid')

# %%
sb.distplot(mpp['Rank'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rank', ylabel='Density'>

# %%
mpp
# Out:
#      Rank            Company  Revenue ($B)  F.Y.  Employees  Market cap. ($B)  \
# 96     96           Flexport          1.27  2020     2000.0               NaN
# 97     97            LogMeIn          1.26  2019     3974.0              4.21
# 98     98         Craigslist          1.00  2018     1000.0               NaN
# 99     99               Grab          1.00  2018     6000.0               NaN
# 100   100  Ultimate Software          1.00  2018     5000.0               NaN
#
#         Headquarters  Founded                     Industry
# 96     San Francisco     2013  Software freight forwarding
# 97            Boston     2003                     Software
# 98     San Francisco     1995                  Classifieds
# 99         Singapore     2012               Transportation
# 100  Weston, Florida     1993                     Software

# %%
sb.relplot(x='F.Y.',y='Rank',data=mpp,col='F.Y.',hue="Founded",style='Founded',kind="scatter")

# %%
sb.catplot(x='F.Y.',y='Founded',kind='box',data=mb)

# %%
sb.regplot(x='Rank',y='Founded',data=mb)
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='Founded'>

# %%
sb.pairplot(mb)

# %%
sb.pairplot(mb,hue='Employees',palette='Set1')
